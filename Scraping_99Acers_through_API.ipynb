# %%
# Install below for widgets : Uncomment below to install
# !pip install ipywidgets -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.2 MB/s eta 0:00:00

# %%
#@title Import Libraries
import pandas as pd
import requests
from google.colab import files
import ipywidgets as widgets
from IPython.display import display
import json
import os

# %%
#@title Headers
url = "https://www.99acres.com/api-aggregator/discovery/srp/search"

headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_2) AppleWebKit/514.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.24",
    "sec-ch-ua-platform": "\"Windows\"",
    "referer": "https://www.99acres.com/",
    "sec-fetch-site": "same-origin",
    "authority": "www.99acres.com"
}

params = {
    "page": "1",
    "page_size": "1500",
    "platform": "DESKTOP",
    "city": "1"
}

# %%
#@title CITY ID DICT
#@markdown Every city has a ID through which data are fetched

#@markdown RUN This cell to load a City ID dictionary.


CITY_ID_DICT = {'1': 'Delhi|NCR (All)', '2': 'North Delhi', '3': 'South Delhi', '4': 'East Delhi', '5': 'West Delhi', '6': 'Central Delhi', '7': 'Noida', '8': 'Gurgaon', '9': 'Ghaziabad', '10': 'Faridabad', '12': 'Mumbai (All)', '13': 'Mumbai Harbour', '14': 'Central Mumbai suburbs', '15': 'Navi Mumbai', '16': 'South Mumbai', '17': 'Mumbai South West', '19': 'Pune', '20': 'Bangalore (All)', '21': 'Bangalore North', '22': 'Bangalore East', '23': 'Bangalore Central', '25': 'Kolkata (All)', '26': 'Kolkata North', '27': 'Kolkata South', '28': 'Kolkata East', '29': 'Kolkata West', '30': 'Kolkata Central', '32': 'Chennai (All)', '33': 'Chennai North', '34': 'Chennai South', '35': 'Chennai Central', '36': 'Chennai West', '38': 'Hyderabad (All)', '45': 'Ahmedabad (All)', '46': 'Gandhinagar', '47': 'Ahmedabad South', '48': 'Ahmedabad East', '49': 'Ahmedabad West', '52': 'Anantapur', '53': 'Guntakal', '54': 'Guntur', '55': 'Kurnool', '56': 'Nellore', '57': 'Nizamabad', '58': 'Rajahmundry', '60': 'Tirupati', '61': 'Vijayawada', '62': 'Visakhapatnam', '63': 'Warangal', '64': 'Andhra Pradesh Others', '65': 'Itanagar', '66': 'Arunachal Pradesh Others', '67': 'Guwahati', '68': 'Silchar', '69': 'Assam Others', '70': 'Bhagalpur', '71': 'Patna', '72': 'Bihar Others', '73': 'Chandigarh', '74': 'Bhilai', '75': 'Raipur', '76': 'Chattisgarh Others', '77': 'Dadra & Nagar Haveli', '78': 'Daman & Diu', '80': 'Panjim', '81': 'Vasco Da Gama', '82': 'Goa Others', '84': 'Anand', '86': 'Bharuch', '87': 'Bhavnagar', '88': 'Bhuj', '90': 'Gir', '91': 'Jamnagar', '92': 'Kandla', '93': 'Porbandar', '94': 'Rajkot', '95': 'Surat', '96': 'Vadodara', '97': 'Gujarat Others', '98': 'Ambala', '101': 'Karnal', '102': 'Kurukshetra', '103': 'Panipat', '104': 'Rohtak', '105': 'Haryana Others', '106': 'Dalhousie', '107': 'Dharamsala', '108': 'Kulu/Manali', '109': 'Shimla', '110': 'Himachal Pradesh Others', '111': 'Jammu', '112': 'Srinagar', '113': 'Jammu & Kashmir Others', '114': 'Bokaro', '115': 'Dhanbad', '116': 'Jamshedpur', '117': 'Ranchi', '118': 'Belgaum', '119': 'Bellary', '120': 'Bidar', '121': 'Dharwad', '122': 'Gulbarga', '123': 'Hubli', '124': 'Kolar', '125': 'Mangalore', '126': 'Mysore', '127': 'Karnataka Others', '128': 'Calicut', '130': 'Ernakulam', '131': 'Kochi', '132': 'Kollam', '133': 'Kottayam', '135': 'Palakkad', '137': 'Thrissur', '138': 'Trivandrum', '139': 'Kerala Others', '140': 'Bhopal', '141': 'Gwalior', '142': 'Indore', '143': 'Jabalpur', '144': 'Ujjain', '145': 'Madhya Pradesh Others', '146': 'Ahmednagar', '147': 'Aurangabad', '148': 'Jalgaon', '149': 'Kolhapur', '150': 'Nagpur', '151': 'Nasik', '153': 'Maharashtra Others', '154': 'Imphal', '155': 'Manipur Others', '156': 'Shillong', '157': 'Meghalaya Others', '158': 'Aizwal', '159': 'Mizoram Others', '160': 'Dimapur', '161': 'Nagaland Others', '162': 'Bhubaneswar', '163': 'Cuttack', '164': 'Paradeep', '165': 'Puri', '166': 'Rourkela', '167': 'Orissa Others', '168': 'Pondicherry', '169': 'Amritsar', '170': 'Jalandhar', '171': 'Ludhiana', '172': 'Mohali', '173': 'Pathankot', '174': 'Patiala', '175': 'Punjab Others', '176': 'Ajmer', '177': 'Jaipur', '178': 'Jaisalmer', '179': 'Jodhpur', '180': 'Kota', '181': 'Udaipur', '182': 'Rajasthan Others', '183': 'Gangtok', '184': 'Sikkim Others', '185': 'Coimbatore', '186': 'Erode', '187': 'Hosur', '188': 'Madurai', '189': 'Ooty', '190': 'Salem', '191': 'Tirunelveli', '192': 'Trichy', '193': 'Vellore', '194': 'Tamil Nadu Others', '195': 'Agartala', '196': 'Tripura Others', '197': 'Agra', '198': 'Aligarh', '199': 'Allahabad', '200': 'Bareilly', '201': 'Faizabad', '203': 'Gorakhpur', '204': 'Kanpur', '205': 'Lucknow', '206': 'Mathura', '207': 'Meerut', '209': 'Varanasi', '210': 'Uttar Pradesh Others', '211': 'Dehradun', '212': 'Uttarakhand Others', '213': 'Durgapur', '214': 'Kharagpur', '215': 'West Bengal Others', '216': 'Other Cities', '217': 'Bangalore South', '218': 'Mumbai Andheri-Dahisar', '219': 'Thane', '220': 'Dwarka Delhi', '221': 'International', '222': 'Greater Noida', '223': 'Maharashtra', '224': 'Karnataka', '225': 'Gujarat', '226': 'West Bengal', '227': 'Tamil Nadu', '228': 'Andhra Pradesh', '229': 'Arunachal Pradesh', '230': 'Assam', '231': 'Bihar', '232': 'Chattisgarh', '233': 'Goa', '234': 'Haryana', '235': 'Himachal Pradesh', '236': 'Jammu & Kashmir', '237': 'Jharkhand', '238': 'Kerala', '239': 'Madhya Pradesh', '240': 'Manipur', '241': 'Meghalaya', '242': 'Mizoram', '243': 'Nagaland', '244': 'Orissa', '245': 'Punjab', '246': 'Rajasthan', '247': 'Sikkim', '248': 'Tripura', '249': 'Uttar Pradesh', '250': 'Uttarakhand', '251': 'Sonipat', '252': 'Bangalore West', '253': 'Rudrapur', '254': 'Nainital', '255': 'Shahjahanpur', '256': 'Panchkula', '257': 'Union Territory', '262': 'Other Hotspots', '263': 'Jharkhand Others', '264': 'Haridwar', '266': 'Roorkee', '268': 'Secunderabad', '269': 'Hyderabad', '271': 'Vrindavan', '272': 'Konkan', '273': 'Wayanad', '274': 'Mumbai Beyond Thane', '275': 'Mira Road And Beyond', '276': 'Alwar', '277': 'Bhilwara', '278': 'Alappuzha', '279': 'Baddi', '280': 'Asansol', '281': 'Haldia', '282': 'Midnapore', '283': 'Siliguri', '284': 'Dubai', '285': 'Hissar', '286': 'Idukki', '287': 'Bhatinda', '288': 'Saharanpur', '289': 'Bhiwadi', '290': 'Dindigul', '291': 'Australia', '292': 'Other Middle East', '293': 'Malaysia', '294': 'Other International', '295': 'Shirdi', '296': 'Bikaner', '297': 'Nalgonda', '298': 'East Godavari', '299': 'Dholpur', '300': 'Satara', '301': 'Coorg / Madikeri', '302': 'Sri Ganganagar', '303': 'Tirupur', '304': 'Rishikesh', '305': 'Kodaikanal', '306': 'Palani', '307': 'Pollachi', '308': 'Nagerkoil', '309': 'Karimnagar', '310': 'Margao', '311': 'Karur', '314': 'United Kingdom', '315': 'Hapur', '316': 'Moga', '317': 'Andaman & Nicobar', '318': 'Port Blair', '320': 'Jhajjar', '321': 'Junagadh', '322': 'Lonavala', '323': 'North Goa', '324': 'South Goa', '325': 'Mussoorie', '326': 'Bahadurgarh', '327': 'Ongole', '328': 'Angul', '329': 'Dhulia', '330': 'Bulandshahr', '331': 'Dharuhera', '332': 'Prakasham', '333': 'Srikakulam', '334': 'Mahabubnagar', '335': 'Haldwani', '336': 'Khanna', '337': 'Kasargod', '338': 'Hanumangarh', '339': 'Lavasa', '340': 'Khammam', '341': 'Solan', '342': 'Tonk', '343': 'Chikamagalur', '344': 'Kakinada', '345': 'Greece', '346': 'Bilaspur', '347': 'Jhansi', '348': 'Palanpur', '349': 'Radhanpur', '350': 'United States Of America', '351': 'Damoh', '352': 'Nagaur', '353': 'Ranikhet', '357': 'Thailand', '358': 'Shantiniketan', '359': 'China', '360': 'Japan', '361': 'Singapore', '362': 'South Korea', '363': 'United Arab Emirates', '364': 'Saudi Arabia', '365': 'New Zealand', '366': 'Orlando', '367': 'Karjat', '368': 'Anjar', '369': 'Kasara', '371': 'Sangli', '372': 'Bagpat', '373': 'Sawantwadi', '374': 'Dapoli', '375': 'Muzaffar Nagar', '376': 'Prabudh Nagar', '377': 'Vizianagaram', '378': 'Neemrana', '380': 'Tumkur', '381': 'Vapi', '382': 'Ratnagiri', '383': 'Cyprus', '386': 'Jagdalpur', '387': 'Darbhanga', '389': 'Muzaffarpur', '391': 'Madhubani', '392': 'Sakleshpur', '393': 'Irinjalakuda', '394': 'Khajuraho', '395': 'Sikar', '396': 'Palwal', '397': 'Navsari', '398': 'Karwar', '399': 'Pauri Garhwal', '400': 'Rewari', '401': 'Hathras', '402': 'Barmer', '403': 'Gandhidham', '404': 'Sindhudurg', '405': 'Phulera', '406': 'Kannur', '407': 'Udupi', '408': 'Darjeeling', '409': 'Kumarakom', '410': 'Kumhari', '411': 'Ropar', '412': 'Aruppukkottai', '414': 'Karuppayurani', '415': 'Guruvayoor', '416': 'Palghar', '417': 'Akola', '418': 'Katni', '419': 'Mahabaleshwar', '420': 'Panchgani', '421': 'Raigad', '422': 'Shrivardhan', '423': 'Chaukhutia', '424': 'Godhra', '425': 'Dwarka', '426': 'Mettupalayam', '428': 'Kheda', '429': 'Suri', '430': 'Wardha', '431': 'Moradabad', '432': 'Samdari', '433': 'New Tehri', '434': 'Khandala', '435': 'Yavatmal', '436': 'Solapur', '437': 'Nandurbar', '438': 'Chitradurga', '439': 'Gadag', '440': 'Channapatna', '441': 'Mandya', '442': 'Jajpur', '443': 'Vidisha', '444': 'Kanchipuram', '445': 'Kotdwara', '446': 'Chapra', '447': 'Jorhat', '448': 'Gadarwara', '449': 'Begusarai', '450': 'Sirohi', '451': 'Mirzapur', '452': 'Ottapalam', '453': 'Nadiad', '454': 'Lansdowne', '455': 'Bardhaman', '456': 'Amravati', '457': 'Burhanpur', '458': 'Rajpura', '459': 'Bhiwani', '460': 'Tenali', '461': 'Shimoga', '462': 'Valsad', '463': 'Mahesana', '464': 'Kutch', '465': 'Kasauli', '466': 'Kadi', '467': 'Viramgam', '468': 'Mount Abu', '470': 'Nellikuppam', '471': 'Cuddalore', '472': 'Tiruvannamalai', '473': 'Virudhunagar', '475': 'Nagapattinam', '476': 'Kanyakumari', '477': 'Khambhat', '478': 'Thanjavur', '479': 'Sagar', '480': 'Villupuram', '482': 'Bhadravathi', '483': 'Digha', '484': 'Yamuna Nagar', '485': 'Jhunjhunu', '486': 'Latur', '487': 'Theni', '488': 'Jalpaiguri', '490': 'Panagar', '491': 'Barnala', '492': 'Sirsa', '493': 'Bankura', '494': 'Balasore', '495': 'Malappuram', '496': 'Bharatpur', '497': 'Balotra', '498': 'Ganjam', '499': 'Gaya', '500': 'Durg', '501': 'Berhampur', '502': 'Hoshiarpur', '503': 'Jalore', '504': 'Deoghar', '505': 'Sangrur', '506': 'Chandrapur', '507': 'Raigarh', '508': 'Bhusawal', '509': 'Nanded', '510': 'Dhenkanal', '511': 'Dausa', '512': 'North & Middle Andaman', '513': 'Machilipatnam', '514': 'Patan', '515': 'Satna', '516': 'Karad', '517': 'Shahdol', '518': 'Jharsuguda', '519': 'Morbi', '520': 'West Godavari', '521': 'Rewa', '522': 'Eluru', '523': 'Punalur', '524': 'Kadapa', '525': 'Hindupur', '526': 'Hoshangabad', '527': 'Sambalpur', '528': 'Arrah', '529': 'Contai', '530': 'Dewas', '531': 'Pali', '532': 'Davangere', '533': 'Vijayapura', '534': 'Kangra', '535': 'Churu', '536': 'Sawaimadhopur', '537': 'Deesa', '538': 'Bagalkote', '539': 'Kathua', '540': 'Thiruvarur', '541': 'Botad', '542': 'Almora', '543': 'Bhandara', '544': 'Malda', '545': 'Hassan', '546': 'Karaikudi', '547': 'Visnagar', '548': 'Narasaraopet', '549': 'Tadepalligudem', '550': 'Murshidabad', '551': 'Chittoor', '552': 'Kapurthala', '553': 'Firozabad', '554': 'Pilibhit', '555': 'Mandsaur', '556': 'Morena', '557': 'Jehanabad', '558': 'Chittorgarh', '559': 'Bhimavaram', '560': 'Shamli', '561': 'Surendranagar', '562': 'Bahraich', '563': 'Phagwara', '564': 'Beawar', '565': 'Ratlam', '566': 'Chhindwara', '567': 'Thoothukudi', '568': 'Kendujhar', '569': 'Osmanabad', '570': 'Gondia', '571': 'Bundi', '572': 'Bhatapara', '573': 'Korba', '574': 'Gudivada', '575': 'Raebareli', '576': 'Fatehabad', '577': 'Rampur', '578': 'Anandpur Sahib', '579': 'Morinda', '580': 'Rupnagar', '581': 'Bassi Pathana', '582': 'Sabarkantha', '583': 'Unnao', '584': 'Panchmahal', '585': 'Fatehgarh Sahib', '586': 'Barabanki', '587': 'Sirhind', '588': 'Banswara', '589': 'Raichur', '590': 'Amreli', '591': 'Kannauj', '592': 'Krishnagiri', '593': 'Pudukkottai', '594': 'Amroha', '595': 'Parwanoo', '596': 'Sirmaur', '597': 'Daryapur', '598': 'Buldana', '599': 'Dakshina Kannada', '600': 'Hazaribagh', '601': 'Robertsganj', '602': 'Sasaram', '603': 'Palitana', '604': 'Purulia', '605': 'Dumka', '606': 'Ramgarh', '608': 'Beed', '609': 'Gadhinglaj', '610': 'Orai', '43012': 'Bhadrak', '43081': 'Azamgarh', '43332': 'Amaravati', '43447': 'Banaskantha', '43470': 'Jalna', '43482': 'Birbhum', '43789': 'Bettiah', '44498': 'Buxar', '44557': 'Sitarganj', '44626': 'Dhule', '44831': 'Sitapur', '44944': 'Pathanamthitta', '45030': 'Hardoi', '45247': 'Umaria', '45754': 'Golaghat', '45845': 'Godda', '45846': 'Dahod', '45847': 'Sundergarh', '45848': 'Dhamtari', '45849': 'Mahasamund', '45850': 'Raisen', '45851': 'Betul', '45852': 'Dhar', '45853': 'Khandwa', '45854': 'Panna', '45855': 'Chhatarpur', '45856': 'Harda', '45857': 'Singrauli', '45858': 'Guna', '45859': 'Ashoknagar', '45956': 'Bangkok', '45971': 'Dhampur', '46034': 'Barshi', '46035': 'Dang', '46217': 'California', '46218': 'Colorado', '46219': 'Texas', '46220': 'Florida', '46221': 'Georgia', '46222': 'Arizona', '46224': 'Maine', '46225': 'Indiana', '46226': 'Arkansas', '46227': 'Illinois', '46228': 'New Mexico', '46230': 'Duluth', '46345': 'Balaghat', '46572': 'Muktsar', '46667': 'Rajpipla', '46834': 'Gonda', '46858': 'Purnea', '46881': 'Melbourne', '46998': 'Dharmapuri', '47143': 'Barpeta', '47208': 'East Champaran', '47237': 'Shikohabad', '47309': 'Etah', '47318': 'Udham Singh Nagar', '47320': 'Medak', '47323': 'Sangareddy', '47324': 'Siddipet District', '47334': 'Krishna district', '47336': 'Modasa', '47439': 'Bihar Sharif', '47626': 'Bargarh', '47643': 'Faridkot', '47651': 'Koppal', '47654': 'Dibrugarh', '48019': 'Bageshwar', '48088': 'Washim', '48323': 'Parbhani', '48362': 'Baripada', '48363': 'Bhadravati', '48426': 'Berhampore', '48522': 'Hinganghat', '48680': 'Seoni', '48801': 'Khargone', '48802': 'Sillod', '48803': 'Hingoli', '48809': 'Alirajpur', '48957': 'Sivaganga', '48976': 'Karimganj', '49022': 'Narsinghpur', '49023': 'Barwani', '49038': 'Bhojpur', '750434': 'Gondal', '752493': 'Neemuch', '753275': 'Tikamgarh', '755617': 'East Singhbhum', '758497': 'Ghazipur', '759376': 'Dohad', '765300': 'Shivpuri', '765337': 'Malegaon', '766177': 'Rajsamand', '766291': 'Gurdaspur', '766639': 'Mainpuri', '767005': 'Bhadra', '768553': 'Kashid', '768559': 'Fatehpur', '770852': 'Sujangarh', '772819': 'Uttara Kannada', '773627': 'Dungarpur', '786209': 'Namakkal', '786353': 'Rajnandgaon', '786373': 'Janjgir-Champa', '787895': 'Araria', '792380': 'Balangir', '792394': 'Anuppur', '792423': 'Rajgarh', '793213': 'Urun Islampur', '793214': 'Surguja', '793219': 'Bemetara', '793249': 'Uttarkashi', '793289': 'Mandla', '795852': 'Nadia', '795911': 'Jaunpur', '796674': 'Nilgiris', '797129': 'Siwan', '797862': 'Hajipur', '798505': 'Chamarajanagar', '799347': 'Jind', '802945': 'Kondagaon', '803628': 'Mandi', '805279': 'Sharjah', '805280': 'Abu Dhabi', '805386': 'Kaithal', '810073': 'Kampala', '810083': 'Ras Al-Khaimah', '814384': 'Saraikela Kharsawan', '847162': 'Mukerian', '857746': 'Rayagada', '870731': 'Nagaon', '870732': 'Telangana', '875458': 'Gadchiroli', '887721': 'Gajapati', '887925': 'Cooch Behar', '894770': 'Jhalawar', '897278': 'Ballia', '899668': 'Udhampur', '900973': 'Lakhimpur', '905550': 'Saharsa', '905726': 'Bongaon', '1000406': 'Kaushambi', '1001353': 'Tiruchengode', '1001608': 'Farrukhabad', '1004250': 'Una', '1006403': 'Mancherial', '1006405': 'Karmala', '1007223': 'Samastipur', '1007769': 'Ferozepur', '1008514': 'Nabadwip', '1008530': 'Ahmedabad North', '1010560': 'Adilabad', '1011611': 'Tezpur', '1011833': 'Fazilka', '1011834': 'Mansa', '1014094': 'Etawah', '1018553': 'London', '1021659': 'Sivasagar', '1022657': 'Bhadohi', '1023763': 'Supaul', '1024168': 'Basti', '1027480': 'Bhadradri Kothagudem', '1034231': 'Nuapada', '1034293': 'Madhepura', '1039099': 'Kokrajhar', '1040252': 'Borsad', '1040661': 'Lalitpur', '1041267': 'Oman', '1042055': 'Narnaul', '1042719': 'Suryapet', '1042906': 'Telangana Others', '1044434': 'Tarn Taran', '1045782': 'Giridih', '1046586': 'Deoria', '1047908': 'Ayodhya', '1049033': 'Ramagundam', '1049034': 'Kendrapara', '1050404': 'Ranebennuru', '1050820': 'Anantnag', '1051920': 'North 24 Parganas', '1053705': 'Khunti', '1054286': 'Munger', '1054881': 'Sultanpur', '1055668': 'Haveri', '1055885': 'Auraiya', '1057415': 'Khagaria', '1058543': 'Nuh', '1060735': 'Akbarpur', '1062103': 'South 24 Parganas', '1062766': 'Alipurduar', '1063205': 'Palampur', '1063261': 'Sheohar', '1063585': 'Arwal', '1064527': 'Madha', '1065731': 'Silvassa', '1066484': 'Kot Kapura', '1068076': 'Uttar Dinajpur', '1068077': 'Raiganj', '1070274': 'Budaun', '1070285': 'Nalanda', '1070407': 'Nagarkurnool', '1070595': 'Hamirpur', '1071064': 'Kamrup Metropolitan', '1071606': 'Hailakandi', '1075008': 'Rajanna Sircilla', '1075277': 'Gobardanga', '1075722': 'Delhi', '1076928': 'Bilaspur', '1077199': 'Datia', '1077389': 'Katihar', '1077754': 'Baran', '1078443': 'Koraput', '1078469': 'Bolpur', '1078545': 'Harihara', '1079020': 'Khordha', '1079033': 'Jagatsinghpur', '1081480': 'Kaimur', '1081787': 'Nawada', '1083808': 'Aurangabad(Bihar)', '1083838': 'Mewat', '1084621': 'Banda', '1085871': 'East Khasi Hills', '1087253': 'Koderma', '1087254': 'Jhumri Telaiya', '1088285': 'Wanaparthy', '1088603': 'Mau', '1088973': 'Rohtas', '1089044': 'Balasinor', '1089576': 'Daltonganj', '1090000': 'Balrampur', '1091347': 'Bhabua', '1091577': 'Kinnaur', '1091882': 'Gopalganj', '1093908': 'Pithoragarh', '1094579': 'Chamba', '1094909': 'Bijnor', '1095138': 'Chatra', '1095995': 'Chamoli', '1096023': 'Indi', '1096732': 'Sehore', '1100581': 'Tapi', '1101222': 'Maharajganj', '1103195': 'Sant Kabir Nagar', '1103196': 'Sambhal', '1103302': 'Biswanath', '1104473': 'Ladakh', '1111485': 'Kumuram Bheem Asifabad', '1115298': 'Shaheed Bhagat Singh Nagar', '1122778': 'Niwari', '1123018': 'Kandhamal', '1123468': 'Agar', '1123765': 'Mahoba', '1124548': 'Narmada', '1125785': 'Champawat', '1125856': 'Ambedkar Nagar'}
# print(CITY_ID_DICT)

# %% [markdown]
# ## Download Files

# %%
#@title Set PARAMS
#@markdown Run this cell to enable the form.
# Set Default value for Widget
NUM_PAGE = 10
page_size = 1500


# Create dropdown widget for city selection
city_dropdown = widgets.Dropdown(
    options=list(CITY_ID_DICT.values()),
    description='Select City:'
)

# Create input fields for page and page size
page_input = widgets.IntText(
    value=NUM_PAGE,
    max=100,
    description='Page:'
)

page_size_input = widgets.IntText(
    value=page_size,
    max=12000,
    description='Page Size:'
)
# Create a button to update parameters
update_button = widgets.Button(description="Update Params")

# Display the widgets
display(city_dropdown, page_input, page_size_input, update_button)

# Function to update params and create a directory based on widget values
def update_params(change):
  global params
  global city_dir
  global NUM_PAGE
  city_name = city_dropdown.value
  city_id = [i for i in CITY_ID_DICT if CITY_ID_DICT[i]==city_name][0]
  page = page_input.value
  page_size = page_size_input.value

  # Use the values to set params for your API request
  params['city'] = city_id
  params['page_size'] = page_size
  NUM_PAGE = page
  # print("Params:", params)

  return params
# Link the widget values to the update_params function
city_dropdown.observe(update_params, names='value')
page_input.observe(update_params, names='value')
page_size_input.observe(update_params, names='value')

def params_update(_):
  print('Parameters Updated')
  print(params)
  print("Now Run Below Cells")
# Link the button to the update_params function
update_button.on_click(params_update)
# Out:
# Dropdown(description='Select City:', options=('Delhi|NCR (All)', 'North Delhi', 'South Delhi', 'East Delhi', '…
# IntText(value=10, description='Page:')
# IntText(value=1500, description='Page Size:')
# Button(description='Update Params', style=ButtonStyle())
# Parameters Updated
# {'page': '1', 'page_size': 1500, 'platform': 'DESKTOP', 'city': '71'}
# Now Run Below Cells

# %%
#@title START Scrapping
#@markdown Run This cell to start scrapping

#@markdown After scrapping is done, click on Download files button

#@markdown (Allow downlading multiple files)
MAIN_DF = pd.DataFrame()
FACETS = {}

# Create a progress bar widget
progress_bar = widgets.IntProgress(
    value=0,
    min=0,
    max=NUM_PAGE+1,
    description='Progress:',
    bar_style='info',
    style={'bar_color': 'blue'}
)

# Create a label widget for displaying additional information
info_label = widgets.Label()

# Display the progress bar
display(progress_bar, info_label)

for p in range(1,NUM_PAGE+1):
  params['page'] = p
  # Requesting
  response = requests.get(url, headers=headers, params=params)

  if response.status_code == 200:
    data = response.json()

  else:
    print(f"Request failed while page-{p} with status code:", response.status_code)

  facets_tmp = data['facets']
  df1 = pd.DataFrame(data['properties'])
  MAIN_DF = pd.concat([df1, MAIN_DF], ignore_index=True).drop_duplicates(['PROP_ID'])


  # Combine values for common keys and update FACETS
  for key, value in FACETS.items():
      if key in facets_tmp:
          if isinstance(value, list):
              if isinstance(facets_tmp[key], list):
                  value.extend(facets_tmp[key])
              else:
                  value.append(facets_tmp[key])
          else:
              if isinstance(facets_tmp[key], list):
                  facets_tmp[key] = [value] + facets_tmp[key]
              else:
                  facets_tmp[key] = [value, facets_tmp[key]]

  # Add keys from dict2 that are not in dict1
  for key, value in facets_tmp.items():
      if key not in FACETS:
          if isinstance(value, list):
              FACETS[key] = value
          else:
              FACETS[key] = [value]
  progress_bar.value += p
  # Update the info label with the current page or percentage
  info_label.value = f"Pages completed : {p} / {NUM_PAGE}"

# Convert DataFrame to CSV and save it
csv_filename = f"real_estate-{city_dropdown.value}.csv"
MAIN_DF.to_csv(csv_filename, index=False)

# Save dictionary as JSON
json_filename = f"facets-{city_dropdown.value}.json"
with open(json_filename, "w") as json_file:
    json.dump(FACETS, json_file)

# Create a button to trigger downloads
def download_files(_):
    files.download(csv_filename)
    files.download(json_filename)

download_button = widgets.Button(description="Download Files")
download_button.on_click(download_files)
display(download_button)
# Out:
# IntProgress(value=0, bar_style='info', description='Progress:', max=31, style=ProgressStyle(bar_color='blue'))
# Label(value='')
# Button(description='Download Files', style=ButtonStyle())

# %% [markdown]
# ## SAVE directly on Google Drive

# %%
#@title G-Drive Mount
#@markdown Run this cell and authenticate with your google account
from google.colab import drive
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Set your Project DIR Here
PROJECT_DIR = ''

# JSON file whihc has ID's of all city name
# CITY_ID_JSON = '/city_w_id.json'
city_dir = None

# Set Default Value for PARAMS Widget
NUM_PAGE = 10
page_size = 1500

# %%
#@title SET PARAMS
# Load the city mapping data from the JSON file
# with open(CITY_ID_JSON, "r") as file:
#   city_id_mapping = json.load(file)

# Create dropdown widget for city selection
city_dropdown = widgets.Dropdown(
    options=list(CITY_ID_DICT.values()),
    description='Select City:'
)

# Create input fields for page and page size
page_input = widgets.IntText(
    value=NUM_PAGE,
    max=100,
    description='Page:'
)

page_size_input = widgets.IntText(
    value=page_size,
    max=12000,
    description='Page Size:'
)
# Create a button to update parameters
update_button = widgets.Button(description="Update Params")

# Display the widgets
display(city_dropdown, page_input, page_size_input, update_button)

# Function to update params and create a directory based on widget values
def update_params(change):
  global params
  global city_dir
  global NUM_PAGE
  city_name = city_dropdown.value
  city_id = [i for i in CITY_ID_DICT if CITY_ID_DICT[i]==city_name][0]
  page = page_input.value
  page_size = page_size_input.value

  # Use the values to set params for your API request
  params['city'] = city_id
  params['page_size'] = page_size
  NUM_PAGE = page
  # print("Params:", params)

  # Create a directory for the selected city if it doesn't exist
  project_dir = PROJECT_DIR
  city_dir = os.path.join(project_dir, city_name)
  if not os.path.exists(city_dir):
      os.makedirs(city_dir)
      print(f"Directory '{city_name}' created.")

  return params
# Link the widget values to the update_params function
city_dropdown.observe(update_params, names='value')
page_input.observe(update_params, names='value')
page_size_input.observe(update_params, names='value')


def params_update(_):
  print('Parameters Updated')
  print(params)
  print("Now Run Below Cells")
# Link the button to the update_params function
update_button.on_click(params_update)
# Out:
# Dropdown(description='Select City:', options=('Delhi|NCR (All)', 'North Delhi', 'South Delhi', 'East Delhi', '…
# IntText(value=30, description='Page:')
# IntText(value=1500, description='Page Size:')
# Button(description='Update Params', style=ButtonStyle())
# Directory 'Patna' created.
# Parameters Updated
# {'page': 30, 'page_size': 1500, 'platform': 'DESKTOP', 'city': '71'}
# Now Run Below Cells

# %%
#@title START SCRAPING

MAIN_DF = pd.DataFrame()
FACETS = {}

# Create a progress bar widget
progress_bar = widgets.IntProgress(
    value=0,
    min=0,
    max=NUM_PAGE+1,
    description='Progress:',
    bar_style='info',
    style={'bar_color': 'blue'}
)

# Create a label widget for displaying additional information
info_label = widgets.Label()

# Display the progress bar
display(progress_bar, info_label)

for p in range(1,NUM_PAGE+1):
  params['page'] = p
  # Requesting
  response = requests.get(url, headers=headers, params=params)

  if response.status_code == 200:
    data = response.json()

  else:
    print(f"Request failed while page-{p} with status code:", response.status_code)

  facets_tmp = data['facets']
  df1 = pd.DataFrame(data['properties'])
  MAIN_DF = pd.concat([df1, MAIN_DF], ignore_index=True).drop_duplicates(['PROP_ID'])


  # Combine values for common keys and update FACETS
  for key, value in FACETS.items():
      if key in facets_tmp:
          if isinstance(value, list):
              if isinstance(facets_tmp[key], list):
                  value.extend(facets_tmp[key])
              else:
                  value.append(facets_tmp[key])
          else:
              if isinstance(facets_tmp[key], list):
                  facets_tmp[key] = [value] + facets_tmp[key]
              else:
                  facets_tmp[key] = [value, facets_tmp[key]]

  # Add keys from dict2 that are not in dict1
  for key, value in facets_tmp.items():
      if key not in FACETS:
          if isinstance(value, list):
              FACETS[key] = value
          else:
              FACETS[key] = [value]
  progress_bar.value += p
  # Update the info label with the current page or percentage
  info_label.value = f"Pages completed : {p} / {NUM_PAGE}"


def save_data(_):
  json_file_path = os.path.join(city_dir, f'facets-{city_dropdown.value}.json')
  csv_file_path = os.path.join(city_dir, f'real_estate-{city_dropdown.value}.csv')
  if os.path.isfile(csv_file_path):
  # Append DataFrame to the existing file without header
      MAIN_DF.to_csv(csv_file_path, mode='a', header=False, index=False)
  else:
      # Write DataFrame to the file with header
      MAIN_DF.to_csv(csv_file_path, mode='a', header=True, index=False)
  print("CSV File Saved")

  # Save the dictionary as a JSON file
  with open(json_file_path, "w") as json_file:
      json.dump(FACETS, json_file, indent=4)
  print("JSON File Saved")
# Create a button to update parameters
update_button = widgets.Button(description="Save Data")
display(update_button)
# Link the button to the update_params function
update_button.on_click(save_data)
# Out:
# IntProgress(value=0, bar_style='info', description='Progress:', max=51, style=ProgressStyle(bar_color='blue'))
# Label(value='')
# Button(description='Save Data', style=ButtonStyle())
# CSV File Saved
# JSON File Saved
